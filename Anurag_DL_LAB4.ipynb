# %% [markdown]
# #Load IMDB dataset

# %%
from tensorflow.keras.datasets import imdb

vocab_size = 10000

(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=vocab_size)

print(f"Training samples: {len(x_train)}")
print(f"Testing samples: {len(x_test)}")
# Out:
# Training samples: 25000
# Testing samples: 25000

# %% [markdown]
# #Preprocessing

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

max_len = 250

x_train = pad_sequences(x_train, maxlen=max_len, padding='post')
x_test = pad_sequences(x_test, maxlen=max_len, padding='post')

print(x_train.shape)
print(x_test.shape)
# Out:
# (25000, 250)
# (25000, 250)

# %% [markdown]
# #Build LSTM Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout

model = Sequential()

model.add(Embedding(input_dim=vocab_size, output_dim=32, input_length=max_len))

model.add(LSTM(32))

model.add(Dropout(0.5))

model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_3 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #Compile & Train Model

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    x_train, y_train,
    epochs=10,
    batch_size=128,
    validation_split=0.2
)
# Out:
# Epoch 1/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 27s 151ms/step - accuracy: 0.5324 - loss: 0.6907 - val_accuracy: 0.5884 - val_loss: 0.6717
# Epoch 2/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 24s 156ms/step - accuracy: 0.5697 - loss: 0.6904 - val_accuracy: 0.5654 - val_loss: 0.6684
# Epoch 3/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 43s 169ms/step - accuracy: 0.5961 - loss: 0.6280 - val_accuracy: 0.5958 - val_loss: 0.6188
# Epoch 4/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 39s 155ms/step - accuracy: 0.6150 - loss: 0.5817 - val_accuracy: 0.6120 - val_loss: 0.6055
# Epoch 5/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 41s 155ms/step - accuracy: 0.6548 - loss: 0.5388 - val_accuracy: 0.6040 - val_loss: 0.6134
# Epoch 6/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 25s 158ms/step - accuracy: 0.6493 - loss: 0.5219 - val_accuracy: 0.6014 - val_loss: 0.6185
# Epoch 7/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 24s 152ms/step - accuracy: 0.6515 - loss: 0.5061 - val_accuracy: 0.6182 - val_loss: 0.6301
# Epoch 8/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 24s 153ms/step - accuracy: 0.6769 - loss: 0.4885 - val_accuracy: 0.8294 - val_loss: 0.5844
# Epoch 9/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 43s 167ms/step - accuracy: 0.8627 - loss: 0.3438 - val_accuracy: 0.8586 - val_loss: 0.4006
# Epoch 10/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 24s 155ms/step - accuracy: 0.9139 - loss: 0.2490 - val_accuracy: 0.8618 - val_loss: 0.3944

# %% [markdown]
# #Evaluate Model

# %%
loss, accuracy = model.evaluate(x_test, y_test)

print(f"Test Loss: {loss}")
print(f"Test Accuracy: {accuracy}")
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 18s 23ms/step - accuracy: 0.8542 - loss: 0.4078
# Test Loss: 0.40783289074897766
# Test Accuracy: 0.854200005531311

# %% [markdown]
# #Predict a sample

# %%
prediction = model.predict(x_test[:5])
print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# [[0.06145247]
#  [0.99875414]
#  [0.99554926]
#  [0.73286647]
#  [0.976829  ]]

# %%
predicted_labels = (prediction > 0.5).astype(int)
print(predicted_labels)
# Out:
# [[0]
#  [1]
#  [1]
#  [1]
#  [1]]
